# %% [markdown]
# <center> <span style="color:indigo">Machine Learning e Inferencia Bayesiana</span> </center>
#
# <center>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Centro_Universitario_del_Guadalajara_Logo.png/640px-Centro_Universitario_del_Guadalajara_Logo.png" alt="Drawing" style="width: 600px;"/>
# </center>
#
# <center> <span style="color:DarkBlue">  Tema 13: Redes neuronales, clasificacion </span>  </center>
# <center> <span style="color:Blue"> M. en C. Iván A. Toledano Juárez </span>  </center>
#
# # Clasificación con PyTorch
#
# Este notebook está basado en las notas de **MRDBourke** y utiliza datos del famoso dataset del **[Titanic](https://www.kaggle.com/competitions/titanic/overview)** disponible en Kaggle.
# El objetivo es construir un modelo de **clasificación binaria** con **PyTorch**, que prediga la probabilidad de supervivencia de los pasajeros.
#
# ## Objetivo
# Entrenar una red neuronal simple que aprenda a clasificar a los pasajeros del Titanic según las características disponibles, estimando si **sobrevivieron (1)** o **no sobrevivieron (0)**.
#
# ## Variables del dataset
#
# | Variable | Descripción | Valores posibles |
# |-----------|--------------|------------------|
# | `survival` | Supervivencia | 0 = No, 1 = Sí |
# | `pclass` | Clase del boleto | 1 = 1ª, 2 = 2ª, 3 = 3ª |
# | `sex` | Sexo | — |
# | `age` | Edad (en años) | — |
# | `sibsp` | Nº de hermanos / cónyuges a bordo | — |
# | `parch` | Nº de padres / hijos a bordo | — |
# | `ticket` | Número de boleto | — |
# | `fare` | Tarifa pagada | — |
# | `cabin` | Número de cabina | — |
# | `embarked` | Puerto de embarque | C = Cherbourg, Q = Queenstown, S = Southampton |
#
# ---
#
# A lo largo del notebook se realizará el **preprocesamiento de datos**, la **construcción del modelo**, y la **evaluación de su desempeño** mediante métricas de clasificación como **exactitud** y **matriz de confusión**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
from torch import nn

# %matplotlib inline

# %%
df_titanic_train = pd.read_csv("titanic_data/train.csv")
df_titanic_test = pd.read_csv("titanic_data/test.csv")

# Algunas variables no son necesarias

variables = ['Pclass','Sex', 'Age', 'SibSp','Parch', 'Fare', 'Cabin', 'Embarked','Survived']
variables_2 = variables.copy()
variables_2.remove('Survived')

df_titanic_train = df_titanic_train[variables]
df_titanic_test = df_titanic_test[variables_2]


print(df_titanic_train.head(5))

print('Shape(Train)',df_titanic_train.shape)
print('Shape(test)',df_titanic_test.shape)
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0       3    male  22.0      1      0   7.2500   NaN        S         0
# 1       1  female  38.0      1      0  71.2833   C85        C         1
# 2       3  female  26.0      0      0   7.9250   NaN        S         1
# 3       1  female  35.0      1      0  53.1000  C123        S         1
# 4       3    male  35.0      0      0   8.0500   NaN        S         0
# Shape(Train) (891, 9)
# Shape(test) (418, 8)

# %%
df_titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Age       714 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Cabin     204 non-null    object
#  7   Embarked  889 non-null    object
#  8   Survived  891 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
# Valores nulos
df_titanic_train.isna().sum().to_frame().head(83)
# Out:
#             0
# Pclass      0
# Sex         0
# Age       177
# SibSp       0
# Parch       0
# Fare        0
# Cabin     687
# Embarked    2
# Survived    0

# %%
# Valores nulos
df_titanic_test.isna().sum().to_frame().head(83)
# Out:
#             0
# Pclass      0
# Sex         0
# Age        86
# SibSp       0
# Parch       0
# Fare        1
# Cabin     327
# Embarked    0

# %% [markdown]
# Podemos ignorar la variable Cabin. Para la variable de edad, (... podríamos rellenarlo con la media .... o no).

# %%
columns = ['Pclass','Sex', 'Age', 'SibSp','Parch', 'Fare', 'Embarked','Survived']
columns_2 = columns.copy()
columns_2.remove('Survived')

df2_titanic_train = df_titanic_train.copy()
df2_titanic_test = df_titanic_test.copy()

df2_titanic_train = df2_titanic_train[columns]
df2_titanic_test = df2_titanic_test[columns_2]

df2_titanic_train['Age'] = df2_titanic_train['Age'].fillna(df2_titanic_train['Age'].mean())
df2_titanic_test['Age'] = df2_titanic_test['Age'].fillna(df2_titanic_test['Age'].mean())

# %%
# Variables categoricas y numéricas

categorical = df2_titanic_train.select_dtypes(include=['object']).columns.tolist()
numerical = df2_titanic_train.select_dtypes(include='number').columns.tolist()

# %%
# Variables dummy con pandas

df3_titanic_train = df2_titanic_train.copy()
df3_titanic_test = df2_titanic_test.copy()


for element in categorical:
    tab_dummy = pd.get_dummies(df3_titanic_train[element],prefix=element, dtype=int)
    data_new = df3_titanic_train.join(tab_dummy)
    df3_titanic_train = data_new
    
for element in categorical:
    tab_dummy = pd.get_dummies(df3_titanic_test[element],prefix=element, dtype=int)
    data_new = df3_titanic_test.join(tab_dummy)
    df3_titanic_test = data_new

# Quitamos las columnas redundantes
to_keep = [element for element in df3_titanic_train.columns if element not in categorical]
to_keep_2 = [element for element in df3_titanic_test.columns if element not in categorical]

df3_titanic_train = df3_titanic_train[to_keep]
df3_titanic_test = df3_titanic_test[to_keep_2]

# %%
df3_titanic_train
# Out:
#      Pclass        Age  SibSp  Parch     Fare  Survived  Sex_female  Sex_male  \
# 0         3  22.000000      1      0   7.2500         0           0         1
# 1         1  38.000000      1      0  71.2833         1           1         0
# 2         3  26.000000      0      0   7.9250         1           1         0
# 3         1  35.000000      1      0  53.1000         1           1         0
# 4         3  35.000000      0      0   8.0500         0           0         1
# ..      ...        ...    ...    ...      ...       ...         ...       ...
# 886       2  27.000000      0      0  13.0000         0           0         1
# 887       1  19.000000      0      0  30.0000         1           1         0
# 888       3  29.699118      1      2  23.4500         0           1         0
# 889       1  26.000000      0      0  30.0000         1           0         1
# 890       3  32.000000      0      0   7.7500         0           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 11 columns]

# %%
# Features y class
X_list = to_keep.copy()
X_list.remove('Survived')
Y_list = 'Survived'

# %%
# Dataframes a array

X_df = df3_titanic_train[X_list]
Y_df = df3_titanic_train[Y_list]

# %%
X_df_train, X_df_test, Y_df_train, Y_df_test = train_test_split(X_df, Y_df, test_size=0.2, random_state=42)

# %%
X_array_train = X_df_train.to_numpy()
Y_array_train = Y_df_train.to_numpy()      
X_array_test = X_df_test.to_numpy()
Y_array_test = Y_df_test.to_numpy()

# %% [markdown]
# ## Arquitectura de una red neuronal para clasificación
#
# | Hiperparámetro | Clasificación binaria | Clasificación multiclase |
# | --- | --- | --- |
# | Capa de entrada | El mismo que el número de variables de entrada | Igual que clasificación binaria|
# | Capas ocultas | Depende del problema. Teóricamente puede ir de 1 a infinito | Igual que clasificación binaria|
# | Neuronas por capa oculta | Depende del probleme. Usualmente entre 10 y 512 | Igual que clasificación binaria|
# | Capas de salida | 1 (una por clase) | Una por cada clase|
# | Función de activación de capas ocultas | Típica: ReLU, pero puede ser cualquiera. | Igual que clasificación binaria|
# | Función de activación de capa de salida | Típica: Sigmoid | [Softmax](https://pytorch.org/docs/stable/generated/torch.nn.Softmax.html) |
# | Loss Function | [Binary crossentropy](https://pytorch.org/docs/stable/generated/torch.nn.BCELoss.html) | [Crossentropy](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html)|
# | Optimizador | SGD, [Adam](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html) | Igual que clasificación binaria|

# %% [markdown]
# ## Arrays a tensores, y sets de entrenamiento y validación

# %%
#X = torch.from_numpy(X_array).type(torch.float)
#y = torch.from_numpy(Y_array).type(torch.float)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, 
 #                                                   y, 
 #                                                   test_size=0.2, # 20% test, 80% train
 #                                                   random_state=42) # make the random split reproducible

#len(X_train), len(X_test), len(y_train), len(y_test)

# %%
X_array_train = torch.from_numpy(X_array_train).type(torch.float)
Y_array_train = torch.from_numpy(Y_array_train).type(torch.float)   
X_array_test = torch.from_numpy(X_array_test).type(torch.float)
Y_array_test = torch.from_numpy(Y_array_test).type(torch.float)

# %% [markdown]
# ## Creando el modelo
#
# Ya tenemos nuestros datos listos, así que es momento de **construir un modelo** de clasificación utilizando **PyTorch**.
# El proceso lo dividiremos en varios pasos clave:
#
# 1. Configurar código **agnóstico al dispositivo** (CPU o GPU).
# 2. Construir un modelo **subclasificando `nn.Module`**.
# 3. Definir una **función de pérdida** y un **optimizador**.
# 4. Crear un **bucle de entrenamiento**.
#
# La buena noticia es que ya hemos seguido estos pasos antes (en el notebook anterior), solo que ahora los **ajustaremos para un problema de clasificación**.
#
# ---
#
# ## Configuración del dispositivo
#
# Comenzamos importando las librerías necesarias y preparando el entorno para que el modelo pueda ejecutarse en **CPU o GPU**, según disponibilidad. Si tu equipo tiene acceso a una GPU compatible, pytorch la utilizará automáticamente. Esto permite que todo --datos, modelos y tensores -- se gestionesn en el dispositivo adecuado.

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.backends.mps.is_available()
# Out:
# True

# %%
# Fijar el tipo de hardware
#device = "cuda" if torch.cuda.is_available() else "cpu"
#device = "mps" if torch.mps.is_available() else "cpu"
#device
device = 'mps'

# %%
# Shapes de tensores

X_array_train.shape
# Out:
# torch.Size([712, 10])

# %% [markdown]
# ## Creación del modelo
#
# Queremos un modelo que reciba nuestros datos de entrada `X`(features) y produzca una predicción `y`, es decir, un tipo de problema supervisado. Para ello, definiremos una clase en python que,
#
# * Herede de `nn.module` (como todos los modelos de pytorch)
# * Cree dos capas lineales `nn.linear` en el constructor, con las dimensiones de entrada y salida adecuadas para nuestros datos.
# * Implemente un método `forward()` que defina la propagación hacia adelante del modelo
# * Instanciamos el modelo y lo envíamos al dispositivo configurado

# %%
# 1. Construimos la clase del modelo con la subclase nn.Module
class ModelV0(nn.Module):
    def __init__(self):
        super().__init__()
        # 2. Creamos las capas de entrada (lineales) capaces de manejar los features de entrada y clase de salida
        self.layer_1 = nn.Linear(in_features=10, out_features=20) # toma 10 features (X), produce 20 features
        self.layer_2 = nn.Linear(in_features=20, out_features=1) # toma 20 features, produce 1 feature (y)
    
    # 3. Definimos un método para la propagación (forward)
    def forward(self, x):
        # Regresa la capa de salida de layer_2, un solo features, con el mismo shape que y
        # El calculo pasa sobre layer_1 y luego su output es el input de layer_2
        return self.layer_2(self.layer_1(x)) 

# 4. Creamos una instancia con el modelo y se manda al hardware
model_0 = ModelV0().to(device)
model_0
# Out:
# ModelV0(
#   (layer_1): Linear(in_features=10, out_features=20, bias=True)
#   (layer_2): Linear(in_features=20, out_features=1, bias=True)
# )

# %% [markdown]
# La primera capa (`layer_1`) recibe 2 características de entrada (`in_features=2`) y produce 5 salidas (`out_features=5`). Estas 5 salidas se conocen como unidades ocultas, y permiten al modelo aprender **patrones más complejos**.
#
# La segunda capa (`layer_2`) toma esas 5 características y las transforma en una única salida (`out_features=1`), que corresponden a la predicción del modelo.
#
# **NOTA**: El número de unidades ocultas las elige uno. Más unidades podrían capturar patrones más complejos, pero también pueden provocar sobreajuste y entrenamiento más lento.
#
# ## `nn.Sequential`
#
# El método `nn.Sequential()` ejecuta la propagación hacia adelante en el orden en que aparecen las capas, simplificando la sintaxis cuando no se requieren pasos intermedios personalizados.

# %%
# Se replica el modelV0
model_0 = nn.Sequential(
    nn.Linear(in_features=10, out_features=20),
    nn.Linear(in_features=20, out_features=1)
).to(device)

model_0
# Out:
# Sequential(
#   (0): Linear(in_features=10, out_features=20, bias=True)
#   (1): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
# Hacemos predicciones con el modelo
untrained_preds = model_0(X_array_test.to(device))
print(f"Length of predictions: {len(untrained_preds)}, Shape: {untrained_preds.shape}")
print(f"Length of test samples: {len(Y_array_test)}, Shape: {Y_array_test.shape}")
print(f"\nFirst 10 predictions:\n{untrained_preds[:10]}")
print(f"\nFirst 10 test labels:\n{Y_array_test[:10]}")
# Out:
# Length of predictions: 179, Shape: torch.Size([179, 1])
# Length of test samples: 179, Shape: torch.Size([179])
#
# First 10 predictions:
# tensor([[ 3.8286],
#         [ 2.7081],
#         [ 2.1845],
#         [ 6.9061],
#         [ 2.9450],
#         [15.8466],
#         [ 2.4001],
#         [ 4.1815],
#         [ 2.2029],
#         [ 5.7211]], device='mps:0', grad_fn=<SliceBackward0>)
#
# First 10 test labels:
# tensor([1., 0., 0., 1., 1., 1., 1., 0., 1., 1.])

# %% [markdown]
# ## Configuración de la función de pérdida y el optimizador
#
# Ya hemos configurado modelos, así que ahora toca definir **cómo aprenderá**, a través de una **función de pérdida** (*loss function*) y un **optimizador**.
#
# En el notebook previo ya usamos estos conceptos, pero es importante notar que **diferentes tipos de problemas requieren distintas funciones de pérdida.**
#
# ---
#
# ## Función de pérdida
#
# La función de pérdida (también llamada *cost function*) mide **qué tan equivocadas son las predicciones del modelo**. Mientras más alto sea su valor, peor está aprendiendo el modelo.  El entrenamiento consiste en **minimizar esta pérdida**.
#
# Ejemplos comunes:
#
# | Función / Optimizador | Tipo de problema | Código en PyTorch |
# |------------------------|------------------|-------------------|
# | Stochastic Gradient Descent (SGD) | Clasificación, regresión, muchos otros | `torch.optim.SGD()` |
# | Adam Optimizer | Clasificación, regresión, muchos otros | `torch.optim.Adam()` |
# | Binary Cross Entropy (BCE) | Clasificación binaria | `torch.nn.BCELoss()` o `torch.nn.BCEWithLogitsLoss()` |
# | Cross Entropy | Clasificación multiclase | `torch.nn.CrossEntropyLoss()` |
# | Mean Absolute Error (MAE) / L1 Loss | Regresión | `torch.nn.L1Loss()` |
# | Mean Squared Error (MSE) / L2 Loss | Regresión | `torch.nn.MSELoss()` |
#
# ---
#
# ## Elección para nuestro caso
#
# Como estamos trabajando con un **problema de clasificación binaria**, la opción más adecuada es usar una **pérdida de entropía cruzada binaria** (*binary cross entropy loss*).
#
# PyTorch ofrece dos versiones:
#
# - `torch.nn.BCELoss()`
#   Calcula la entropía cruzada binaria entre las predicciones y las etiquetas.
#
# - `torch.nn.BCEWithLogitsLoss()`
#   Hace lo mismo, pero **integra internamente una función sigmoide** (`nn.Sigmoid`).
#   Esto la hace **más estable numéricamente** y generalmente se recomienda sobre la anterior.
#
# > 💡 **Recomendación:**
# > Usa `torch.nn.BCEWithLogitsLoss()` en la mayoría de los casos de clasificación binaria.
# > Evita aplicar manualmente un `Sigmoid` si utilizas esta versión.
#
# ---
#
# ## Optimizador
#
# El optimizador es el algoritmo que **ajusta los pesos del modelo** para minimizar la pérdida.  Podemos usar el clásico **descenso de gradiente estocástico (SGD)** o el más moderno **Adam**. Ambos funcionan bien, pero empezaremos con **SGD** para mayor claridad.

# %%
# Loss Function
loss_fn = nn.BCEWithLogitsLoss() # BCEWithLogitsLoss = sigmoid built-in

# Optimizador
optimizer = torch.optim.SGD(params=model_0.parameters(), 
                            lr=0.01)

# %%
# Métrica de evaluación (accuracy)
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item() # torch.eq() calcula si dos tensores son iguales
    acc = (correct / len(y_pred)) * 100 
    return acc

# %% [markdown]
# ## Entrenamiento del modelo
#
# Antes de realizar el loop de entrenamiento, veamos que sale del modelo al realizar una propagación hacia adelante, usando los datos de validacion.

# %%
# Los 5 primeros outputs
y_logits = model_0(X_array_test.to(device))[:5]
y_logits
# Out:
# tensor([[3.8286],
#         [2.7081],
#         [2.1845],
#         [6.9061],
#         [2.9450]], device='mps:0', grad_fn=<SliceBackward0>)

# %% [markdown]
# Como el modelo todavía **no ha sido entrenado**, sus salidas son esencialmente **valores aleatorios**.  Durante la **propagación hacia adelante**, los datos pasan a través de las dos capas lineales definidas, las cuales aplican internamente la siguiente ecuación:
#
# \begin{equation}
# y = x \cdot w^T + \mathrm{bias}
# \end{equation}
#
# Los valores resultantes $y$ de esta operación, así como los que produce el modelo, se conocen como **_logits_**.  En un modelo puramente lineal, estos logits representarían simplemente **valores numéricos** sin restricción en su rango (pueden ser negativos o positivos).
#
# Si aplicamos una **función de activación sigmoide** sobre ellos, podemos convertir dichos valores en **probabilidades** dentro del intervalo $(0, 1)$, lo que nos permite interpretar el resultado como:
#
# \begin{equation}
# \text{probabilidad de clase positiva} = \sigma(y) = \frac{1}{1 + e^{-y}}
# \end{equation}
#
# De este modo, al establecer un **umbral (threshold)** —por ejemplo, 0.5— podemos transformar las probabilidades en una **clasificación binaria**:
#
# - Si $\sigma(y) \ge 0.5$ → clase **1 (positivo)**
# - Si $\sigma(y) < 0.5$ → clase **0 (negativo)**
#
# > 💡 **Nota:** En PyTorch, cuando se utiliza `nn.BCEWithLogitsLoss`, la función sigmoide ya está incorporada dentro de la función de pérdida, por lo que **no es necesario aplicarla manualmente** en la salida del modelo.

# %%
# Sigmoid
y_pred_probs = torch.sigmoid(y_logits)
y_pred_probs
# Out:
# tensor([[0.9787],
#         [0.9375],
#         [0.8989],
#         [0.9990],
#         [0.9500]], device='mps:0', grad_fn=<SigmoidBackward0>)

# %%
# Redondeamos para obtener una clasificación (threshold 0.5)
#y_preds = torch.round(y_pred_probs)
threshold = 0.5
y_preds = (y_pred_probs >= threshold).float()

y_pred_labels = torch.round(torch.sigmoid(model_0(X_array_test.to(device))[:5]))

# Checamos igualdad
print(torch.eq(y_preds.squeeze(), y_pred_labels.squeeze()))

# Quitamos la dimensión extra
y_preds.squeeze()
# Out:
# tensor([True, True, True, True, True], device='mps:0')
# tensor([1., 1., 1., 1., 1.], device='mps:0')

# %%
Y_array_test[:5]
# Vemos que ahora si tenemos las etiquetas que queremos
# Out:
# tensor([1., 0., 0., 1., 1.])

# %%
torch.manual_seed(88) # semilla aleatoria

# Número de epocas
epochs = 2000

# Poner los datos en el hardware target
X_train, y_train = X_array_train.to(device), Y_array_train.to(device)
X_test, y_test = X_array_test.to(device), Y_array_test.to(device)


train_loss_list = []
test_loss_list = []


# Loop de training y eval
for epoch in range(epochs):
    ### Training
    model_0.train()

    # 1. Forward propagation (el modelo regresa logits)
    y_logits = model_0(X_train).squeeze() # squeeze para remover `1` dimension extra
    y_pred = torch.round(torch.sigmoid(y_logits)) # logits -> pred probs -> pred labls
  
    # 2. Se calcula loss/accuracy
    # loss = loss_fn(torch.sigmoid(y_logits), # Using nn.BCELoss you need torch.sigmoid()
    #                y_train) 
    loss = loss_fn(y_logits, # nn.BCEWithLogitsLoss acepta los logits de salida
                   y_train) 
    
    acc = accuracy_fn(y_true=y_train, 
                      y_pred=y_pred) 

    # 3. Zero grad para el optimizador
    optimizer.zero_grad()

    # 4. Back propagation
    loss.backward()

    # 5. Optimizador
    optimizer.step()

    ### Evaluacion
    model_0.eval()
    with torch.inference_mode():
        # 1. Forward 
        test_logits = model_0(X_test).squeeze() 
        test_pred = torch.round(torch.sigmoid(test_logits))
        # 2. loss/accuracy
        test_loss = loss_fn(test_logits,
                            y_test)
        
        
        test_acc = accuracy_fn(y_true=y_test,
                               y_pred=test_pred)

    #
# Epoch: 1970 | Loss: 0.49214, Accuracy: 77.53% | Test loss: 0.46789, Test acc: 81.56%
# Epoch: 1980 | Loss: 0.49203, Accuracy: 77.53% | Test loss: 0.46781, Test acc: 81.56%
# Epoch: 1990 | Loss: 0.49193, Accuracy: 77.53% | Test loss: 0.46772, Test acc: 81.56%

# %%
train_loss_list_cpu = torch.tensor(train_loss_list).cpu().detach().numpy()
test_loss_list_cpu = torch.tensor(test_loss_list).cpu().detach().numpy()    
train_loss_list
test_loss_list_cpu
# Out:
# [tensor(0.5234, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5232, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5230, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5227, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5225, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5223, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5221, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5219, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5216, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5214, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5212, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5210, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5208, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5206, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5203, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5201, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5199, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5197, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5195, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5193, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5191, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5189, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5187, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5185, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5182, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5180, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5178, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5176, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5174, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5172, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5170, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5168, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5166, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5164, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5162, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5160, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5158, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5156, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5154, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5152, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5151, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5149, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5147, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5145, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5143, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5141, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5139, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5137, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5135, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5133, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5131, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5130, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5128, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5126, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5124, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5122, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5120, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5119, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5117, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5115, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5113, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5111, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5110, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5108, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5106, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5104, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5102, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5101, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5099, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5097, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5095, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5094, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5092, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5090, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5089, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5087, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5085, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5084, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5082, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5080, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5078, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5077, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5075, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5074, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5072, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5070, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5069, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5067, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5065, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5064, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5062, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5061, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5059, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5057, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5056, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5054, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5053, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5051, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5049, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5048, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5046, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5045, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5043, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5042, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5040, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5039, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5037, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5036, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5034, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5033, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5031, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5030, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5028, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5027, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5025, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5024, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5022, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5021, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5020, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5018, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5017, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5015, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5014, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5012, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5011, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5010, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5008, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5007, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5005, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5004, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5003, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5001, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.5000, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4999, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4997, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4996, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4994, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4993, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4992, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4990, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4989, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4988, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4986, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4985, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4984, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4983, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4981, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4980, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4979, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4977, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4976, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4975, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4974, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4972, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4971, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4970, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4969, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4967, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4966, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4965, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4964, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4962, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4961, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4960, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4959, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4958, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4956, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4955, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4954, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4953, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4952, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4950, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4949, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4948, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4947, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4946, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4945, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4943, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4942, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4941, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4940, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4939, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4938, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4937, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4936, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4934, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4933, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4932, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4931, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4930, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4929, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4928, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4927, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4926, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4925, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4924, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4922, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4921, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4920, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>),
#  tensor(0.4919, device='mps:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)]

# %%
x_array = np.arange(0, 200, 1)
plt.plot(x_array, train_loss_list_cpu, label='Train loss', color='orange')
plt.plot(x_array, test_loss_list_cpu, label='Test loss', color='green')
plt.show()

# %% [markdown]
# ## Mejorando el modelo
#
# Una vez que el modelo básico está funcionando, existen diversas estrategias para **mejorar su desempeño**.  Cada una de las siguientes técnicas busca aumentar la capacidad del modelo para **aprender patrones más complejos** o **ajustarse mejor a los datos**.
#
# ---
#
# ### 1. Añadir más capas
# Cada capa adicional puede incrementar la **capacidad de representación** del modelo, permitiéndole aprender **patrones más abstractos y no lineales**. Agregar más capas hace que la red sea más **profunda**, lo que da origen al término *deep learning*.
#
# ---
#
# ### 2. Añadir más neuronas ocultas
# De forma similar, aumentar el número de **neuronas (unidades ocultas)** dentro de una capa puede mejorar la capacidad del modelo para capturar relaciones complejas entre las variables. Sin embargo, demasiadas neuronas pueden llevar al **sobreajuste (overfitting)**.
#
# ---
#
# ### 3. Entrenar por más épocas
# Dar al modelo más **épocas** (iteraciones completas sobre los datos) permite que los pesos se actualicen más veces, lo que puede mejorar el rendimiento si el modelo aún no ha convergido. Pero un número excesivo de épocas también puede causar **sobreajuste**.
#
# ---
#
# ### 4. Cambiar la función de activación
# Los datos reales rara vez son lineales. Usar funciones de activación **no lineales** (como ReLU, tanh o sigmoid) permite que el modelo aprenda relaciones más complejas.
# Por ejemplo:
# - `nn.ReLU()` → común en redes profundas.
# - `nn.Sigmoid()` → útil en clasificación binaria.
# - `nn.Tanh()` → centrada en 0, útil para ciertos tipos de datos.
#
# ---
#
# ### 5. Ajustar la tasa de aprendizaje
# La **tasa de aprendizaje** (`learning_rate`) controla qué tanto se ajustan los parámetros en cada actualización.
# - Si es **demasiado alta**, el modelo puede **oscilar o divergir**.
# - Si es **demasiado baja**, el aprendizaje será **muy lento** o se quedará estancado en un mínimo local.
#
# Encontrar un valor adecuado requiere **experimentación o búsqueda sistemática (grid/random search)**.
#
# ---
#
# ### 6. Cambiar la función de pérdida
# Cada tipo de problema (clasificación binaria, multiclase, regresión, etc.) requiere una **función de pérdida diferente**.
# Probar distintas opciones puede mejorar la estabilidad o precisión del aprendizaje.
#
# Ejemplo:
# - Clasificación binaria → `nn.BCEWithLogitsLoss()`
# - Clasificación multiclase → `nn.CrossEntropyLoss()`
# - Regresión → `nn.MSELoss()` o `nn.L1Loss()`
#
# ---
#
# ### 7. Transfer learning
# En lugar de entrenar un modelo desde cero, se puede **aprovechar un modelo preentrenado** en un problema similar y **ajustarlo (fine-tuning)** a los nuevos datos.
# Esta técnica es muy útil cuando se dispone de **pocos datos** o se trabaja con **dominios complejos**, como imágenes o texto.
#
# ---
#
# > **NOTA:** No existe una receta única para mejorar el modelo.
# > La práctica más común es **ajustar un hiperparámetro a la vez**, observar su impacto en la pérdida y en las métricas de validación, y repetir el proceso hasta encontrar un equilibrio entre **precisión y generalización**.

# %%
class ModelV1(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=10, out_features=20)
        self.layer_2 = nn.Linear(in_features=20, out_features=20) # capa extra
        self.layer_3 = nn.Linear(in_features=20, out_features=1)
        
    def forward(self, x): 
        # z = self.layer_1(x)
        # z = self.layer_2(z)
        # z = self.layer_3(z)
        # return z
        return self.layer_3(self.layer_2(self.layer_1(x)))

model_1 = ModelV1().to(device)
model_1
# Out:
# ModelV1(
#   (layer_1): Linear(in_features=10, out_features=20, bias=True)
#   (layer_2): Linear(in_features=20, out_features=20, bias=True)
#   (layer_3): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
loss_fn = nn.BCEWithLogitsLoss() 
optimizer = torch.optim.SGD(model_1.parameters(), lr=0.01)

# %%
torch.manual_seed(88) # semilla aleatoria

# Número de epocas
epochs = 5500

# Poner los datos en el hardware target
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# Loop de training y eval
for epoch in range(epochs):
    ### Training
    model_1.train()

    # 1. Forward propagation (el modelo regresa logits)
    y_logits = model_1(X_train).squeeze() # squeeze para remover `1` dimension extra
    y_pred = torch.round(torch.sigmoid(y_logits)) # logits -> pred probs -> pred labls
  
    # 2. Se calcula loss/accuracy
    # loss = loss_fn(torch.sigmoid(y_logits), # Using nn.BCELoss you need torch.sigmoid()
    #                y_train) 
    loss = loss_fn(y_logits,
| Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3370 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3380 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3390 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3400 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3410 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3420 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3430 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3440 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3450 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3460 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3470 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3480 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3490 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3500 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3510 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3520 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3530 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3540 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3550 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3560 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3570 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3580 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3590 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3600 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3610 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3620 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3630 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3640 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3650 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3660 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3670 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3680 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3690 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3700 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3710 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3720 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3730 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3740 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3750 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3760 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3770 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3780 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3790 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3800 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3810 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3820 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3830 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3840 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3850 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3860 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3870 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3880 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3890 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3900 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3910 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3920 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3930 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3940 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3950 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3960 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3970 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3980 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 3990 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4000 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4010 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4020 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4030 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4040 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4050 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4060 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4070 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4080 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4090 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4100 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4110 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4120 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4130 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4140 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4150 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4160 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4170 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4180 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4190 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4200 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4210 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4220 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4230 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4240 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4250 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4260 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4270 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4280 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4290 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4300 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4310 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4320 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4330 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4340 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4350 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4360 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4370 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4380 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4390 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4400 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4410 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4420 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4430 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4440 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4450 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4460 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4470 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4480 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4490 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4500 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4510 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4520 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4530 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4540 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4550 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4560 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4570 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4580 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4590 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4600 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4610 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4620 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4630 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4640 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4650 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4660 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4670 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4680 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4690 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4700 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4710 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4720 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4730 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4740 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4750 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4760 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4770 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4780 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4790 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4800 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4810 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4820 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4830 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4840 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4850 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4860 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4870 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4880 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4890 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4900 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4910 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4920 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4930 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4940 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4950 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4960 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4970 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4980 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 4990 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5000 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5010 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5020 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5030 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5040 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5050 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5060 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5070 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5080 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5090 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5100 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5110 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5120 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5130 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5140 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5150 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5160 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5170 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5180 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5190 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5200 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5210 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5220 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5230 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5240 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5250 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5260 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5270 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5280 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5290 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5300 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5310 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5320 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5330 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5340 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5350 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5360 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5370 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5380 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5390 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5400 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5410 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5420 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5430 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5440 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5450 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5460 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5470 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5480 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%
# Epoch: 5490 | Loss: 0.55312, Accuracy: 68.54% | Test loss: 0.55529, Test acc: 68.72%

# %%
class ModelV2(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=10, out_features=20)
        self.layer_2 = nn.Linear(in_features=20, out_features=20)
        self.layer_3 = nn.Linear(in_features=20, out_features=1)
        self.relu = nn.ReLU() # <- Se añade función de activación ReLU
        # También se puede usar sigmoid, pero se tendría que quitar en la parte de transformación del output 
        # self.sigmoid = nn.Sigmoid()

    def forward(self, x):
      # ReLU se aplica entre capas
       return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

model_3 = ModelV2().to(device)
print(model_3)
# Out:
# ModelV2(
#   (layer_1): Linear(in_features=10, out_features=20, bias=True)
#   (layer_2): Linear(in_features=20, out_features=20, bias=True)
#   (layer_3): Linear(in_features=20, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
torch.manual_seed(88) # semilla aleatoria

# Número de epocas
epochs = 500

# Poner los datos en el hardware target
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# Loop de training y eval
for epoch in range(epochs):
    ### Training
    model_1.train()

    # 1. Forward propagation (el modelo regresa logits)
    y_logits = model_1(X_train).squeeze() # squeeze para remover `1` dimension extra
    y_pred = torch.round(torch.sigmoid(y_logits)) # logits -> pred probs -> pred labls
  
    # 2. Se calcula loss/accuracy
    # loss = loss_fn(torch.sigmoid(y_logits), # Using nn.BCELoss you need torch.sigmoid()
    #                y_train) 
    loss = loss_fn(y_logits, # nn.BCEWithLogitsLoss acepta los logits de salida
                   y_train) 
    acc = accuracy_fn(y_true=y_train, 
                      y_pred=y_pred) 

    # 3. Zero grad para el optimizador
    optimizer.zero_grad()

    # 4. Back propagation
    loss.backward()

    # 5. Optimizador
    optimizer.step()

    ### Evaluacion
    model_1.eval()
    with torch.inference_mode():
        # 1. Forward 
        test_logits = model_1(X_test).squeeze() 
        test_pred = torch.round(torch.sigmoid(test_logits))
        # 2. loss/accuracy
        test_loss = loss_fn(test_logits,
                            y_test)
        test_acc = accuracy_fn(y_true=y_test,
                               y_pred=test_pred)

    # Print cada 10 epocas
    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Loss: {loss:.5f}, Accuracy: {acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")
# Out:
# Epoch: 0 | Loss: 0.58228, Accuracy: 66.85% | Test loss: 0.55589, Test acc: 72.63%
# Epoch: 10 | Loss: 0.58163, Accuracy: 66.85% | Test loss: 0.55529, Test acc: 72.63%
# Epoch: 20 | Loss: 0.58099, Accuracy: 66.85% | Test loss: 0.55470, Test acc: 73.18%
# Epoch: 30 | Loss: 0.58035, Accuracy: 66.85% | Test loss: 0.55411, Test acc: 73.18%
# Epoch: 40 | Loss: 0.57971, Accuracy: 66.99% | Test loss: 0.55352, Test acc: 73.18%
# Epoch: 50 | Loss: 0.57908, Accuracy: 66.99% | Test loss: 0.55293, Test acc: 73.18%
# Epoch: 60 | Loss: 0.57845, Accuracy: 66.99% | Test loss: 0.55235, Test acc: 73.74%
# Epoch: 70 | Loss: 0.57782, Accuracy: 67.13% | Test loss: 0.55177, Test acc: 73.74%
# Epoch: 80 | Loss: 0.57719, Accuracy: 67.28% | Test loss: 0.55119, Test acc: 73.74%
# Epoch: 90 | Loss: 0.57656, Accuracy: 67.42% | Test loss: 0.55061, Test acc: 73.74%
# Epoch: 100 | Loss: 0.57594, Accuracy: 67.56% | Test loss: 0.55004, Test acc: 73.74%
# Epoch: 110 | Loss: 0.57532, Accuracy: 67.56% | Test loss: 0.54947, Test acc: 73.74%
# Epoch: 120 | Loss: 0.57470, Accuracy: 67.56% | Test loss: 0.54890, Test acc: 73.74%
# Epoch: 130 | Loss: 0.57408, Accuracy: 67.56% | Test loss: 0.54834, Test acc: 73.74%
# Epoch: 140 | Loss: 0.57347, Accuracy: 67.70% | Test loss: 0.54778, Test acc: 72.63%
# Epoch: 150 | Loss: 0.57286, Accuracy: 67.70% | Test loss: 0.54722, Test acc: 72.63%
# Epoch: 160 | Loss: 0.57225, Accuracy: 67.70% | Test loss: 0.54666, Test acc: 72.63%
# Epoch: 170 | Loss: 0.57164, Accuracy: 67.70% | Test loss: 0.54611, Test acc: 73.18%
# Epoch: 180 | Loss: 0.57104, Accuracy: 67.70% | Test loss: 0.54556, Test acc: 73.74%
# Epoch: 190 | Loss: 0.57043, Accuracy: 67.84% | Test loss: 0.54502, Test acc: 73.74%
# Epoch: 200 | Loss: 0.56983, Accuracy: 67.84% | Test loss: 0.54448, Test acc: 73.74%
